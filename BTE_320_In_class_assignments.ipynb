# %% [markdown]
# <a href="https://colab.research.google.com/github/gcb2047-byte/BTE-320/blob/main/BTE_320_In_class_assignments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Assignment 1

# %%
sales= float(input("Give the sales value($):"))
tax_rate= float(input("Give the tax rate(%):"))
print (f"Sales: {sales}$")
COGS = sales*.4
print (f"Cost of Goods Sold: {COGS}$")
profit= sales-COGS
print (f"Gross Profit: {profit}$")
taxes= profit*tax_rate/100
print(f"Taxes: {taxes}$")
net= profit-taxes
print(f"Net Income: {net}$")
# Out:
# Give the sales value($):1000
# Give the tax rate(%):3
# Sales: 1000.0$
# Cost of Goods Sold: 400.0$
# Gross Profit: 600.0$
# Taxes: 18.0$
# Net Income: 582.0$

# %% [markdown]
# Assignment 2

# %%
num_1= float(input("Give the first number"))
num_2= float(input("Give the second number"))
operation= (input("Give the operation"))

if operation == "+":
  print (num_1 + num_2)

elif operation == "-":
  print(num_1 - num_2)

elif operation =="*":
  print (num_1 * num_2)

else:
  print("invalid operator. please use +,-,*")
# Out:
# Give the first number1
# Give the second number2
# Give the operation+
# 3.0

# %% [markdown]
# Assignment 3

# %%
print ("Hour", "Fee")
for hour in range (1,9):
  fee= 5+ 2.5* hour
  if fee <10:
    fee=10.0
  elif fee >20:
    fee=20
  print (f" {hour}   {fee}")
# Out:
# Hour Fee
#  1   10.0
#  2   10.0
#  3   12.5
#  4   15.0
#  5   17.5
#  6   20.0
#  7   20
#  8   20
